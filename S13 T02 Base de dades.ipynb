# %% [markdown]
# #### 1.1  Crea una base de dades relacionals senzilla utilitzant MySQL(https://www.mysql.com/) i connecta-la a Python

# %%
# !pip install mysql-connector-python &> /dev/null
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="quinfastic", 
  database="Vendes Establiment"  
)

print(mydb)

# %%
mycursor = mydb.cursor()
mycursor.execute("SHOW TABLES")

for x in mycursor:
    print(x)
# Out:
# ('Client',)
# ('Establiment',)
# ('Producte',)
# ('Tipus de Producte',)
# ('Transacció',)
# ('Treballador',)

# %% [markdown]
# ______

# %% [markdown]
# ![Captura%20de%20pantalla%202022-02-09%20a%20les%2017.16.09.png](attachment:Captura%20de%20pantalla%202022-02-09%20a%20les%2017.16.09.png)

# %% [markdown]
# ______
